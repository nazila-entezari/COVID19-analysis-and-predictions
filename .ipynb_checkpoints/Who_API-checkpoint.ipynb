# %%
# Dependencies
import requests
from pprint import pprint

url = "http://apps.who.int/gho/athena/api/GHO/WHOSIS_000010.json?profile=simple"

response = requests.get(url).json()
pprint(response)

# %%
url = "https://apps.who.int/gho/athena/api/.json"

# url = "https://ghoapi.azureedge.net/api/Dimension"

response1 = requests.get(url).json()

pprint(response1)
# Out:
# {'attribute': [{'display': 'COMMENT', 'label': 'COMMENT'},
#                {'display': 'DS', 'label': 'DS'},
#                {'display': 'FIPS', 'label': 'FIPS'},
#                {'display': 'IOC', 'label': 'IOC'},
#                {'display': 'ISO2', 'label': 'ISO2'},
#                {'display': 'ISO', 'label': 'ISO'},
#                {'display': 'ITU', 'label': 'ITU'},
#                {'display': 'MARC', 'label': 'MARC'},
#                {'display': 'WHO', 'label': 'WHO'},
#                {'display': 'WMO', 'label': 'WMO'},
#                {'display': 'GEOMETRY', 'label': 'GEOMETRY'},
#                {'display': 'MORT', 'label': 'MORT'},
#                {'display': 'LAND_AREA_KMSQ_2012',
#                 'label': 'LAND_AREA_KMSQ_2012'},
#                {'display': 'LANGUAGES_EN_2012', 'label': 'LANGUAGES_EN_2012'},
#                {'display': 'WHO_REGION', 'label': 'WHO_REGION'},
#                {'display': 'WHO_REGION_CODE', 'label': 'WHO_REGION_CODE'},
# ...
